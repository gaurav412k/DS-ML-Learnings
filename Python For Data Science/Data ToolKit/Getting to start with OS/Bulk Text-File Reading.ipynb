# %%
import os

# %%
tx= open('File 1.txt','r')
print(tx.read())
tx.close()
# Out:
# This is file 1

# %%
files = os.listdir()
for i in files:
    tx= open(i,'r')
    print( i , ' : ', tx.read())
    tx.close()
# Out:
# File 1 - Copy (10) - Copy.txt  :  This is file 1
# File 1 - Copy (11) - Copy.txt  :  This is file 1
# File 1 - Copy (12) - Copy - Copy.txt  :  This is file 1
# File 1 - Copy (12) - Copy.txt  :  This is file 1
# File 1 - Copy (13) - Copy - Copy.txt  :  This is file 1
# File 1 - Copy (13) - Copy.txt  :  This is file 1
# File 1 - Copy (14) - Copy.txt  :  This is file 1
# File 1 - Copy (15) - Copy.txt  :  This is file 1
# File 1 - Copy (16) - Copy.txt  :  This is file 1
# File 1 - Copy (17) - Copy.txt  :  This is file 1
# File 1 - Copy (18) - Copy.txt  :  This is file 1
# File 1 - Copy (19) - Copy.txt  :  This is file 1
# File 1 - Copy (2) - Copy - Copy.txt  :  This is file 1
# File 1 - Copy (2) - Copy.txt  :  This is file 1
# File 1 - Copy (2).txt  :  This is file 1
# File 1 - Copy (20) - Copy.txt  :  This is file 1
# File 1 - Copy (21) - Copy.txt  :  This is file 1
# File 1 - Copy (3) - Copy - Copy.txt  :  This is file 1
# File 1 - Copy (3) - Copy.txt  :  This is file 1
# ...
